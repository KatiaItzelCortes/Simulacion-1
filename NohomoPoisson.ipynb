# %% [markdown]
# <a href="https://colab.research.google.com/github/KatiaItzelCortes/Simulacion-1/blob/main/NohomoPoisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
import numpy as np
import matplotlib.pyplot as plt

# %%
def sdldecus():
  t = 0
  Na = 0
  Nd = 0
  n = 0
  A = []
  D = []
  def ti_llegada(lamd, T):
    R1 = r.random()
    t = t -(1/ lamda)*np.log (R1)
    return suma1
  def ti_servicio():
    R2 = r.random()
    return R2
  ta = ti_llegada(t)
  td = float ('int')
  while True:
    #Casi 1
    if ta <= td and ta <= T:
      t = ta
      Na =+ 1
      n =+ 1
      ta = ti_llegada(t)
      if n == 1:
        Y = ti_servicio()
        td = t + Y
      A[Na] = t

      # Caso 2
      elif td < ta and td <= T:
        t = td
        n =- 1
        Nd =+ 1
        if n == 0:
          td = float('inf')
        else:
          Y = ti_servicio()
          td = t + Y
        D[Nd] = t

      # Caso 3
      elif min(ta, td) > T and n > 0:
        t = td
        n -= 1
        Nd += 1
        if n > 0:
          Y = ti_servicio()
          td = t + Y
        D[Nd] = t

      # Caso 4
      elif min(ta, td) > T and n == 0:
        Tp = max(t - T , 0)
        break
